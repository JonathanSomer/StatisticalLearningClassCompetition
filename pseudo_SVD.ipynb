# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import tensorflow as tf
from data_pre_processing.fetch_data import *
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X_train, Y_train = get_X_Y_train()
X_test = get_X_test()

# get number of total users:
n_train_users, _, n_train_movies = X_train.shape
n_test_users, _, n_train_movies = X_test.shape
n_users = n_train_users + n_test_users

all_user_ratings_for_all_train_movies = np.concatenate((X_train[:,1,:], X_test[:,1,:]), axis=0)
all_user_ratings_for_all_train_movies = tf.constant(\
                                                    all_user_ratings_for_all_train_movies, \
                                                    dtype=tf.float32, \
                                                    name="all_user_ratings_for_all_train_movies")

train_users_target_movie_ratings = tf.constant(Y_train,\
                                                dtype=tf.float32, \
                                                name="train_users_target_movie_ratings")

# hyperparamaters: 
n_dimensions = 10
target_loss_dominance = 0.8
regularization_coefficient = 0.01

n_epochs = 100000
learning_rate = 0.1

# Varibles:
train_movies_weights = tf.Variable(tf.random_uniform([n_train_movies, n_dimensions], -1.0, 1.0), name="train_movies_weights")
test_movie_weights = tf.Variable(tf.random_uniform([1, n_dimensions], -1.0, 1.0), name="test_movie_weights")
user_weights = tf.Variable(tf.random_uniform([n_users, n_dimensions], -1.0, 1.0), name="user_weights")


# calculating train loss
predictions = tf.matmul(user_weights, tf.transpose(train_movies_weights))
mask = ~tf.debugging.is_nan(all_user_ratings_for_all_train_movies)
non_nan_rated_movie_predictions = tf.boolean_mask(predictions, mask)
non_nan_rated_movie_ratings = tf.boolean_mask(all_user_ratings_for_all_train_movies, mask)
train_loss = tf.reduce_mean(tf.square(non_nan_rated_movie_predictions-non_nan_rated_movie_ratings), name="train_loss")


# calculating test loss
train_user_weights = user_weights[:n_train_users-1000,:]
target_predictions = tf.matmul(train_user_weights, tf.transpose(test_movie_weights))
error = train_users_target_movie_ratings[:-1000] - target_predictions
target_loss = tf.reduce_mean(tf.square(error), name="target_movie_loss")

regularization_penalty = regularization_coefficient*(tf.norm(train_movies_weights) + tf.norm(test_movie_weights) + tf.norm(user_weights))

alpha = tf.constant(target_loss_dominance, name="alpha")
loss = (1-alpha)*train_loss + alpha*(target_loss)



# rmse of validation set:
validation_train_user_weights = user_weights[n_train_users-1000:n_train_users,:]
validation_target_predictions = tf.matmul(validation_train_user_weights, tf.transpose(test_movie_weights))
validation_error = train_users_target_movie_ratings[-1000:] - validation_target_predictions
validation_rmse = tf.sqrt(tf.reduce_mean(tf.square(validation_error), name="validation_loss"))

optimizer = tf.train.AdamOptimizer()
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    sess.run(init)
#     saver.restore(sess, "./tmp/my_model_lambda=0.01_epoch1000.ckpt")
    print("START:")
    for epoch in range(n_epochs):
        sess.run(training_op)
        
        if epoch % 20 == 0:
            print("Epoch", epoch, "loss =", loss.eval(), "validation_loss =", validation_rmse.eval())
            save_path = saver.save(sess, "./tmp/my_model_n_dims={}_alpha={}_lambda={}_every_20.ckpt".format(n_dimensions,target_loss_dominance,regularization_coefficient))
        if epoch % 500 == 0:
            save_path = saver.save(sess, "./tmp/my_model_n_dims={}_alpha={}_lambda={}_epoch{}.ckpt".format(n_dimensions,target_loss_dominance,regularization_coefficient,epoch))

        save_path = saver.save(sess, "./tmp/my_model_n_dims={}_alpha={}_lambda={}_final.ckpt".format(n_dimensions,target_loss_dominance,regularization_coefficient))
# Out:
# START:
# Epoch 0 loss = 15.276577 validation_loss = 3.8934982
# Epoch 20 loss = 14.816497 validation_loss = 3.8741686
# Epoch 40 loss = 14.394819 validation_loss = 3.8546612
# Epoch 60 loss = 13.954227 validation_loss = 3.8279395
# Epoch 80 loss = 13.453611 validation_loss = 3.7867305
# Epoch 100 loss = 12.881457 validation_loss = 3.725577
# Epoch 120 loss = 12.261228 validation_loss = 3.6401832
# Epoch 140 loss = 11.57214 validation_loss = 3.5288022
# Epoch 160 loss = 10.814808 validation_loss = 3.392137
# Epoch 180 loss = 10.023203 validation_loss = 3.231965
# Epoch 200 loss = 9.22607 validation_loss = 3.0523474
# Epoch 220 loss = 8.421657 validation_loss = 2.8581748
# Epoch 240 loss = 7.6225834 validation_loss = 2.655342
# Epoch 260 loss = 6.856269 validation_loss = 2.4495983
# Epoch 280 loss = 6.1402984 validation_loss = 2.2477582
# Epoch 300 loss = 5.478821 validation_loss = 2.0562937
# Epoch 320 loss = 4.8782587 validation_loss = 1.8821657
# Epoch 340 loss = 4.346813 validation_loss = 1.7314159
# Epoch 360 loss = 3.867237 validation_loss = 1.6090448
# Epoch 380 loss = 3.453398 validation_loss = 1.5177416
# Epoch 400 loss = 3.0935616 validation_loss = 1.4573412
# Epoch 420 loss = 2.784545 validation_loss = 1.4246616
# Epoch 440 loss = 2.5268764 validation_loss = 1.4139872
# Epoch 460 loss = 2.307048 validation_loss = 1.4189069
# Epoch 480 loss = 2.1187558 validation_loss = 1.4329357
# Epoch 500 loss = 1.9581122 validation_loss = 1.4510742
# Epoch 520 loss = 1.8216248 validation_loss = 1.4694057
# Epoch 540 loss = 1.7060795 validation_loss = 1.48529
# Epoch 560 loss = 1.6076348 validation_loss = 1.4972395
# Epoch 580 loss = 1.524737 validation_loss = 1.5045723
# Epoch 600 loss = 1.4542954 validation_loss = 1.5069551
# Epoch 620 loss = 1.3938301 validation_loss = 1.5046624
# Epoch 640 loss = 1.3413789 validation_loss = 1.4980569
# Epoch 660 loss = 1.2961111 validation_loss = 1.4875748
# Epoch 680 loss = 1.2575972 validation_loss = 1.4737672
# Epoch 700 loss = 1.2225186 validation_loss = 1.4572471
# Epoch 720 loss = 1.1930878 validation_loss = 1.4385315
# Epoch 740 loss = 1.167331 validation_loss = 1.4181255
# Epoch 760 loss = 1.1447184 validation_loss = 1.3964791
# Epoch 780 loss = 1.125033 validation_loss = 1.3740398
# Epoch 800 loss = 1.1070114 validation_loss = 1.3512079
# Epoch 820 loss = 1.0909792 validation_loss = 1.3282754
# Epoch 840 loss = 1.0767297 validation_loss = 1.3055371
# Epoch 860 loss = 1.0637172 validation_loss = 1.2832425
# Epoch 880 loss = 1.0519819 validation_loss = 1.2616235
# Epoch 900 loss = 1.0415448 validation_loss = 1.2407981
# Epoch 920 loss = 1.0316243 validation_loss = 1.2208449
# Epoch 940 loss = 1.0229688 validation_loss = 1.2019337
# Epoch 960 loss = 1.014949 validation_loss = 1.1840463
# Epoch 980 loss = 1.0073816 validation_loss = 1.1673049
# Epoch 1000 loss = 1.0004433 validation_loss = 1.1516738
# Epoch 1020 loss = 0.9941474 validation_loss = 1.1371719
# Epoch 1040 loss = 0.9882411 validation_loss = 1.1237578
# Epoch 1060 loss = 0.98318994 validation_loss = 1.1114067
# Epoch 1080 loss = 0.9778857 validation_loss = 1.1001222
# Epoch 1100 loss = 0.97325575 validation_loss = 1.0898248
# Epoch 1120 loss = 0.96873415 validation_loss = 1.0803937
# Epoch 1140 loss = 0.9643911 validation_loss = 1.0718751
# Epoch 1160 loss = 0.96054786 validation_loss = 1.0640953
# Epoch 1180 loss = 0.9570624 validation_loss = 1.0571362
# Epoch 1200 loss = 0.9536546 validation_loss = 1.0508327
# Epoch 1220 loss = 0.95046324 validation_loss = 1.0452001
# Epoch 1240 loss = 0.9474274 validation_loss = 1.0401008
# Epoch 1260 loss = 0.9446551 validation_loss = 1.0355226
# Epoch 1280 loss = 0.9418097 validation_loss = 1.0314304
# Epoch 1300 loss = 0.9391315 validation_loss = 1.027763
# Epoch 1320 loss = 0.93672264 validation_loss = 1.0244896
# Epoch 1340 loss = 0.9344983 validation_loss = 1.0215318
# Epoch 1360 loss = 0.9323232 validation_loss = 1.0189131
# Epoch 1380 loss = 0.9303011 validation_loss = 1.0165349
# Epoch 1400 loss = 0.9282028 validation_loss = 1.0144376
# Epoch 1420 loss = 0.9262855 validation_loss = 1.0125511
# Epoch 1440 loss = 0.92443275 validation_loss = 1.0108589
# Epoch 1460 loss = 0.9225668 validation_loss = 1.0093615
# Epoch 1480 loss = 0.920967 validation_loss = 1.0079441
# Epoch 1500 loss = 0.91931987 validation_loss = 1.0067377
# Epoch 1520 loss = 0.9176655 validation_loss = 1.005647
# Epoch 1540 loss = 0.9161676 validation_loss = 1.0046372
# Epoch 1560 loss = 0.9147234 validation_loss = 1.0037197
# Epoch 1580 loss = 0.91333807 validation_loss = 1.0029233
# Epoch 1600 loss = 0.9119631 validation_loss = 1.0021862
# Epoch 1620 loss = 0.91059506 validation_loss = 1.001495
# Epoch 1640 loss = 0.9092842 validation_loss = 1.0009093
# Epoch 1660 loss = 0.9080681 validation_loss = 1.0003467
# Epoch 1680 loss = 0.90689903 validation_loss = 0.99982667
# Epoch 1700 loss = 0.9057203 validation_loss = 0.9993805
# Epoch 1720 loss = 0.90453166 validation_loss = 0.9989404
# Epoch 1740 loss = 0.9034705 validation_loss = 0.99854875
# Epoch 1760 loss = 0.90246093 validation_loss = 0.9981906
# Epoch 1780 loss = 0.9014925 validation_loss = 0.9978265
# Epoch 1800 loss = 0.900494 validation_loss = 0.99751556
# Epoch 1820 loss = 0.8995673 validation_loss = 0.9972384
# Epoch 1840 loss = 0.8986402 validation_loss = 0.996968
# Epoch 1860 loss = 0.8977367 validation_loss = 0.9967052
# Epoch 1880 loss = 0.89688224 validation_loss = 0.996476
# Epoch 1900 loss = 0.89605975 validation_loss = 0.99626327
# Epoch 1920 loss = 0.8951828 validation_loss = 0.9960384
# Epoch 1940 loss = 0.89443374 validation_loss = 0.9958665
# Epoch 1960 loss = 0.8936284 validation_loss = 0.99569654
# Epoch 1980 loss = 0.89288366 validation_loss = 0.9955264
# Epoch 2000 loss = 0.89216465 validation_loss = 0.9953514
# Epoch 2020 loss = 0.89146024 validation_loss = 0.99518985
# Epoch 2040 loss = 0.89077455 validation_loss = 0.99505347
# Epoch 2060 loss = 0.89014846 validation_loss = 0.99491626
# Epoch 2080 loss = 0.8895245 validation_loss = 0.99479085
# Epoch 2100 loss = 0.88887256 validation_loss = 0.9946465
# Epoch 2120 loss = 0.88828313 validation_loss = 0.994556
# Epoch 2140 loss = 0.8877157 validation_loss = 0.9944232
# Epoch 2160 loss = 0.88716537 validation_loss = 0.9943184
# Epoch 2180 loss = 0.8866316 validation_loss = 0.994217
# Epoch 2200 loss = 0.8860747 validation_loss = 0.9940918
# Epoch 2220 loss = 0.88556063 validation_loss = 0.9939977
# Epoch 2240 loss = 0.885033 validation_loss = 0.9939167
# Epoch 2260 loss = 0.88453466 validation_loss = 0.9938219
# Epoch 2280 loss = 0.8840831 validation_loss = 0.9937392
# Epoch 2300 loss = 0.8836282 validation_loss = 0.99366486
# Epoch 2320 loss = 0.88319516 validation_loss = 0.9935955
# Epoch 2340 loss = 0.88276345 validation_loss = 0.99350035
# Epoch 2360 loss = 0.88234955 validation_loss = 0.99340904
# Epoch 2380 loss = 0.881956 validation_loss = 0.99335176
# Epoch 2400 loss = 0.88154286 validation_loss = 0.99329746
# Epoch 2420 loss = 0.8811754 validation_loss = 0.99322087
# Epoch 2440 loss = 0.8807976 validation_loss = 0.9931578
# Epoch 2460 loss = 0.880438 validation_loss = 0.9930951
# Epoch 2480 loss = 0.8800521 validation_loss = 0.9930384
# Epoch 2500 loss = 0.87972236 validation_loss = 0.99297905
# Epoch 2520 loss = 0.8793854 validation_loss = 0.9929134
# Epoch 2540 loss = 0.87907064 validation_loss = 0.99286073
# Epoch 2560 loss = 0.8787428 validation_loss = 0.9927918
# Epoch 2580 loss = 0.878441 validation_loss = 0.9927406
# Epoch 2600 loss = 0.8781423 validation_loss = 0.99269783
# Epoch 2620 loss = 0.8778562 validation_loss = 0.9926442
# Epoch 2640 loss = 0.8775776 validation_loss = 0.9926045

# %%
def get_model_params(file_path):
    tf.reset_default_graph()

    train_movies_weights = tf.get_variable(name="train_movies_weights", shape=[n_train_movies, n_dimensions])
    test_movie_weights = tf.get_variable(name="test_movie_weights", shape=[1, n_dimensions])
    user_weights = tf.get_variable(name="user_weights", shape=[n_users, n_dimensions])

    saver = tf.train.Saver()
    with tf.Session() as sess:
        saver.restore(sess, file_path)
        return train_movies_weights.eval(), test_movie_weights.eval(), user_weights.eval()

# %%
a,b,c = get_model_params("./tmp/my_model_lambda=0.01_every_20.ckpt")

# %%
a.shape

# %%
b.shape

# %%
c.shape
